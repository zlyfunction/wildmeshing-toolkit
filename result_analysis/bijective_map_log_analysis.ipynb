# %% [markdown]
# # Bijective Map Log Analysis
#
# This notebook analyzes the bijective_map_log_{id}.txt files to categorize them into:
# - **Success**: Files ending with "curves topology is correct" and "finished check curves topology"
# - **Error**: Files with "error" (case insensitive) in the last 20 lines
# - **Incomplete**: Files that don't complete but have no errors
# - **Empty**: Empty files

# %%
import os
import glob
import re
from collections import defaultdict
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Set up paths
log_dir = "test_log"
pattern = "bijective_map_log_*.txt"
log_files = glob.glob(os.path.join(log_dir, pattern))

print(f"Found {len(log_files)} bijective map log files")
print(f"First few files: {log_files[:5]}")
# Out:
# Found 531 bijective map log files
# First few files: ['test_log/bijective_map_log_76055.txt', 'test_log/bijective_map_log_78736.txt', 'test_log/bijective_map_log_37747.txt', 'test_log/bijective_map_log_43549.txt', 'test_log/bijective_map_log_40915.txt']

# %%
def analyze_log_file(filepath):
    """
    Analyze a single log file and return its status.
    
    Returns:
        tuple: (status, details)
        status: 'success', 'error', 'incomplete', 'empty'
        details: additional information about the file
    """
    try:
        # Check if file exists and get size
        if not os.path.exists(filepath):
            return 'missing', 'File does not exist'
        
        file_size = os.path.getsize(filepath)
        if file_size == 0:
            return 'empty', 'File is empty'
        
        with open(filepath, 'r', encoding='utf-8', errors='ignore') as f:
            lines = f.readlines()
        
        if len(lines) == 0:
            return 'empty', 'No content in file'
        
        # Check last two lines for success pattern
        if len(lines) >= 2:
            last_line = lines[-1].strip().lower()
            second_last_line = lines[-2].strip().lower()
            
            if ("curves topology is correct" in second_last_line and 
                "finished check curves topology" in last_line):
                return 'success', f'Completed successfully ({len(lines)} lines)'
        
        # Check last 20 lines for errors
        last_20_lines = lines[-20:] if len(lines) >= 20 else lines
        error_found = False
        error_line = ""
        
        for i, line in enumerate(last_20_lines):
            if re.search(r'error', line, re.IGNORECASE):
                error_found = True
                error_line = line.strip()
                break
        
        if error_found:
            return 'error', f'Error found: "{error_line}" ({len(lines)} lines)'
        
        # If no success pattern and no error, it's incomplete
        return 'incomplete', f'Did not complete ({len(lines)} lines)'
        
    except Exception as e:
        return 'error', f'Exception while reading file: {str(e)}'

# %%
# Analyze all log files
results = {}
status_counts = defaultdict(int)

print("Analyzing log files...\n")

for log_file in sorted(log_files):
    # Extract ID from filename
    filename = os.path.basename(log_file)
    match = re.search(r'bijective_map_log_(\d+)\.txt', filename)
    file_id = match.group(1) if match else 'unknown'
    
    status, details = analyze_log_file(log_file)
    results[file_id] = {
        'filename': filename,
        'status': status,
        'details': details
    }
    status_counts[status] += 1
    
    # Print status for each file
    print(f"{filename}: {status.upper()} - {details}")

print(f"\nAnalyzed {len(results)} files")
# Out:
# Analyzing log files...
#
# bijective_map_log_32770.txt: INCOMPLETE - Did not complete (23279 lines)
# bijective_map_log_34783.txt: INCOMPLETE - Did not complete (57724 lines)
# bijective_map_log_34785.txt: INCOMPLETE - Did not complete (33970 lines)
# bijective_map_log_35269.txt: INCOMPLETE - Did not complete (25217 lines)
# bijective_map_log_36069.txt: SUCCESS - Completed successfully (3935 lines)
# bijective_map_log_36075.txt: SUCCESS - Completed successfully (4201 lines)
# bijective_map_log_80752.txt: SUCCESS - Completed successfully (6375 lines)
# bijective_map_log_80755.txt: SUCCESS - Completed successfully (13900 lines)
# bijective_map_log_80756.txt: SUCCESS - Completed successfully (8119 lines)
# bijective_map_log_80757.txt: SUCCESS - Completed successfully (31926 lines)
# bijective_map_log_80759.txt: SUCCESS - Completed successfully (23297 lines)
# bijective_map_log_80760.txt: INCOMPLETE - Did not complete (26731 lines)
# bijective_map_log_80761.txt: INCOMPLETE - Did not complete (100226 lines)
#
# Analyzed 531 files

# %%
# Create summary statistics
print("\n" + "="*60)
print("SUMMARY STATISTICS")
print("="*60)

total_files = len(results)
print(f"Total files analyzed: {total_files}\n")

for status, count in sorted(status_counts.items()):
    percentage = (count / total_files) * 100
    print(f"{status.upper():<12}: {count:>3} files ({percentage:>5.1f}%)")

print("\nDetailed breakdown:")
print("-" * 40)

# Group by status for detailed view
by_status = defaultdict(list)
for file_id, data in results.items():
    by_status[data['status']].append((file_id, data))

for status in ['success', 'error', 'incomplete', 'empty', 'missing']:
    if status in by_status:
        print(f"\n{status.upper()} files ({len(by_status[status])}):")  
        for file_id, data in sorted(by_status[status]):
            print(f"  {data['filename']}: {data['details']}")
# Out:
# ============================================================
# SUMMARY STATISTICS
# ============================================================
# Total files analyzed: 531
#
# EMPTY       :  14 files (  2.6%)
# ERROR       :   1 files (  0.2%)
# INCOMPLETE  : 177 files ( 33.3%)
# SUCCESS     : 339 files ( 63.8%)
#
# Detailed breakdown:
# ----------------------------------------
#
# SUCCESS files (339):
#   bijective_map_log_36069.txt: Completed successfully (3935 lines)
#   bijective_map_log_36075.txt: Completed successfully (4201 lines)
#   bijective_map_log_36082.txt: Completed successfully (3848 lines)
#   bijective_map_log_36086.txt: Completed successfully (8889 lines)
#   bijective_map_log_36090.txt: Completed successfully (8896 lines)
#   bijective_map_log_36372.txt: Completed successfully (3940 lines)
#   bijective_map_log_36373.txt: Completed successfully (8898 lines)
#   bijective_map_log_37093.txt: Completed successfully (7103 lines)
#   bijective_map_log_37095.txt: Completed successfully (6854 lines)
#   bijective_map_log_37274.txt: Completed successfully (7751 lines)
#   bijective_map_log_37276.txt: Completed successfully (9368 lines)
#   bijective_map_log_37278.txt: Completed successfully (7689 lines)
#   bijective_map_log_37280.txt: Completed successfully (7629 lines)
#   bijective_map_log_37282.txt: Completed successfully (17187 lines)
#   bijective_map_log_37283.txt: Completed successfully (7594 lines)
#   bijective_map_log_37285.txt: Completed successfully (11152 lines)
#   bijective_map_log_37286.txt: Completed successfully (9275 lines)
#   bijective_map_log_37287.txt: Completed successfully (15729 lines)
#   bijective_map_log_37288.txt: Completed successfully (22422 lines)
#   bijective_map_log_37322.txt: Completed successfully (2026 lines)
#   bijective_map_log_37323.txt: Completed successfully (9679 lines)
#   bijective_map_log_37326.txt: Completed successfully (15873 lines)
#   bijective_map_log_37328.txt: Completed successfully (19757 lines)
#   bijective_map_log_37330.txt: Completed successfully (23850 lines)
#   bijective_map_log_37332.txt: Completed successfully (18782 lines)
#   bijective_map_log_37358.txt: Completed successfully (62816 lines)
#   bijective_map_log_43394.txt: Completed successfully (22217 lines)
#   bijective_map_log_43437.txt: Completed successfully (30303 lines)
#   bijective_map_log_43439.txt: Completed successfully (8990 lines)
#   bijective_map_log_43545.txt: Completed successfully (12783 lines)
#   bijective_map_log_43546.txt: Completed successfully (13344 lines)
#   bijective_map_log_43547.txt: Completed successfully (13255 lines)
#   bijective_map_log_43548.txt: Completed successfully (12837 lines)
#   bijective_map_log_43549.txt: Completed successfully (12970 lines)
#   bijective_map_log_43551.txt: Completed successfully (7144 lines)
#   bijective_map_log_43553.txt: Completed successfully (7540 lines)
#   bijective_map_log_43554.txt: Completed successfully (3877 lines)
#   bijective_map_log_43555.txt: Completed successfully (2758 lines)
#   bijective_map_log_43584.txt: Completed successfully (7044 lines)
#   bijective_map_log_43650.txt: Completed successfully (21447 lines)
#   bijective_map_log_43651.txt: Completed successfully (21380 lines)
#   bijective_map_log_43655.txt: Completed successfully (11894 lines)
#   bijective_map_log_43664.txt: Completed successfully (8740 lines)
#   bijective_map_log_43689.txt: Completed successfully (17236 lines)
#   bijective_map_log_43690.txt: Completed successfully (13398 lines)
#   bijective_map_log_43748.txt: Completed successfully (3351 lines)
#   bijective_map_log_43780.txt: Completed successfully (5044 lines)
#   bijective_map_log_43849.txt: Completed successfully (3807 lines)
#   bijective_map_log_43851.txt: Completed successfully (16743 lines)
#   bijective_map_log_43853.txt: Completed successfully (16998 lines)
#   bijective_map_log_43858.txt: Completed successfully (964 lines)
#   bijective_map_log_43860.txt: Completed successfully (947 lines)
#   bijective_map_log_43959.txt: Completed successfully (1492 lines)
#   bijective_map_log_43988.txt: Completed successfully (13510 lines)
#   bijective_map_log_44804.txt: Completed successfully (15082 lines)
#   bijective_map_log_44910.txt: Completed successfully (9791 lines)
#   bijective_map_log_45169.txt: Completed successfully (9219 lines)
#   bijective_map_log_45370.txt: Completed successfully (16141 lines)
#   bijective_map_log_45408.txt: Completed successfully (11022 lines)
#   bijective_map_log_45409.txt: Completed successfully (2600 lines)
#   bijective_map_log_45410.txt: Completed successfully (7110 lines)
#   bijective_map_log_45412.txt: Completed successfully (12632 lines)
#   bijective_map_log_45513.txt: Completed successfully (13574 lines)
#   bijective_map_log_45550.txt: Completed successfully (26552 lines)
#   bijective_map_log_45562.txt: Completed successfully (19926 lines)
#   bijective_map_log_45613.txt: Completed successfully (6254 lines)
#   bijective_map_log_45617.txt: Completed successfully (3032 lines)
#   bijective_map_log_45813.txt: Completed successfully (19562 lines)
#   bijective_map_log_45814.txt: Completed successfully (26098 lines)
#   bijective_map_log_46260.txt: Completed successfully (15496 lines)
#   bijective_map_log_46261.txt: Completed successfully (13862 lines)
#   bijective_map_log_46262.txt: Completed successfully (9507 lines)
#   bijective_map_log_46265.txt: Completed successfully (3752 lines)
#   bijective_map_log_46519.txt: Completed successfully (7055 lines)
#   bijective_map_log_46522.txt: Completed successfully (13251 lines)
#   bijective_map_log_46527.txt: Completed successfully (6820 lines)
#   bijective_map_log_76051.txt: Completed successfully (8293 lines)
#   bijective_map_log_76053.txt: Completed successfully (7390 lines)
#   bijective_map_log_76054.txt: Completed successfully (14185 lines)
#   bijective_map_log_76055.txt: Completed successfully (11932 lines)
#   bijective_map_log_76056.txt: Completed successfully (13576 lines)
#   bijective_map_log_76057.txt: Completed successfully (14071 lines)
#   bijective_map_log_76199.txt: Completed successfully (6911 lines)
#   bijective_map_log_76200.txt: Completed successfully (14699 lines)
#   bijective_map_log_76202.txt: Completed successfully (6723 lines)
#   bijective_map_log_76205.txt: Completed successfully (6919 lines)
#   bijective_map_log_76206.txt: Completed successfully (14699 lines)
#   bijective_map_log_76207.txt: Completed successfully (17397 lines)
#   bijective_map_log_76291.txt: Completed successfully (17382 lines)
#   bijective_map_log_76573.txt: Completed successfully (8153 lines)
#   bijective_map_log_76579.txt: Completed successfully (11317 lines)
#   bijective_map_log_76679.txt: Completed successfully (6536 lines)
#   bijective_map_log_76682.txt: Completed successfully (2723 lines)
#   bijective_map_log_76683.txt: Completed successfully (2260 lines)
#   bijective_map_log_76684.txt: Completed successfully (2263 lines)
#   bijective_map_log_76716.txt: Completed successfully (18337 lines)
#   bijective_map_log_76723.txt: Completed successfully (9787 lines)
#   bijective_map_log_76724.txt: Completed successfully (9932 lines)
#   bijective_map_log_76903.txt: Completed successfully (11162 lines)
#   bijective_map_log_76907.txt: Completed successfully (15211 lines)
#   bijective_map_log_77011.txt: Completed successfully (17398 lines)
#   bijective_map_log_77013.txt: Completed successfully (14107 lines)
#   bijective_map_log_77014.txt: Completed successfully (18711 lines)
#   bijective_map_log_77015.txt: Completed successfully (16908 lines)
#   bijective_map_log_77016.txt: Completed successfully (21660 lines)
#   bijective_map_log_77017.txt: Completed successfully (19568 lines)
#   bijective_map_log_77020.txt: Completed successfully (14886 lines)
#   bijective_map_log_77335.txt: Completed successfully (21888 lines)
#   bijective_map_log_77472.txt: Completed successfully (7683 lines)
#   bijective_map_log_77474.txt: Completed successfully (5852 lines)
#   bijective_map_log_77844.txt: Completed successfully (7726 lines)
#   bijective_map_log_77926.txt: Completed successfully (21005 lines)
#   bijective_map_log_77929.txt: Completed successfully (9055 lines)
#   bijective_map_log_77930.txt: Completed successfully (14129 lines)
#   bijective_map_log_77931.txt: Completed successfully (21318 lines)
#   bijective_map_log_77938.txt: Completed successfully (9333 lines)
#   bijective_map_log_77940.txt: Completed successfully (7472 lines)
#   bijective_map_log_77943.txt: Completed successfully (8059 lines)
#   bijective_map_log_77944.txt: Completed successfully (10186 lines)
#   bijective_map_log_77946.txt: Completed successfully (7959 lines)
#   bijective_map_log_78026.txt: Completed successfully (5298 lines)
#   bijective_map_log_78211.txt: Completed successfully (8431 lines)
#   bijective_map_log_78322.txt: Completed successfully (8994 lines)
#   bijective_map_log_78894.txt: Completed successfully (13287 lines)
#   bijective_map_log_78895.txt: Completed successfully (34077 lines)
#   bijective_map_log_78896.txt: Completed successfully (26290 lines)
#   bijective_map_log_78944.txt: Completed successfully (6557 lines)
#   bijective_map_log_78954.txt: Completed successfully (23575 lines)
#   bijective_map_log_78970.txt: Completed successfully (7383 lines)
#   bijective_map_log_78976.txt: Completed successfully (24620 lines)
#   bijective_map_log_79177.txt: Completed successfully (2506 lines)
#   bijective_map_log_79183.txt: Completed successfully (4937 lines)
#   bijective_map_log_79184.txt: Completed successfully (5312 lines)
#   bijective_map_log_79185.txt: Completed successfully (5238 lines)
#   bijective_map_log_79186.txt: Completed successfully (5954 lines)
#   bijective_map_log_79187.txt: Completed successfully (5949 lines)
#   bijective_map_log_79188.txt: Completed successfully (9202 lines)
#   bijective_map_log_79189.txt: Completed successfully (15696 lines)
#   bijective_map_log_79190.txt: Completed successfully (32600 lines)
#   bijective_map_log_79191.txt: Completed successfully (19133 lines)
#   bijective_map_log_79193.txt: Completed successfully (27141 lines)
#   bijective_map_log_79194.txt: Completed successfully (8395 lines)
#   bijective_map_log_79195.txt: Completed successfully (28340 lines)
#   bijective_map_log_79197.txt: Completed successfully (13115 lines)
#   bijective_map_log_79200.txt: Completed successfully (4404 lines)
#   bijective_map_log_79202.txt: Completed successfully (13270 lines)
#   bijective_map_log_79279.txt: Completed successfully (17207 lines)
#   bijective_map_log_79729.txt: Completed successfully (20735 lines)
#   bijective_map_log_79828.txt: Completed successfully (10843 lines)
#   bijective_map_log_79851.txt: Completed successfully (3114 lines)
#   bijective_map_log_79936.txt: Completed successfully (6925 lines)
#   bijective_map_log_79938.txt: Completed successfully (3162 lines)
#   bijective_map_log_79939.txt: Completed successfully (3011 lines)
#   bijective_map_log_79940.txt: Completed successfully (2885 lines)
#   bijective_map_log_79955.txt: Completed successfully (10893 lines)
#   bijective_map_log_79956.txt: Completed successfully (7201 lines)
#   bijective_map_log_79958.txt: Completed successfully (9314 lines)
#   bijective_map_log_79960.txt: Completed successfully (8861 lines)
#   bijective_map_log_79961.txt: Completed successfully (7772 lines)
#   bijective_map_log_80086.txt: Completed successfully (7366 lines)
#   bijective_map_log_80177.txt: Completed successfully (6514 lines)
#   bijective_map_log_80356.txt: Completed successfully (6735 lines)
#   bijective_map_log_80357.txt: Completed successfully (2136 lines)
#   bijective_map_log_80361.txt: Completed successfully (3215 lines)
#   bijective_map_log_80365.txt: Completed successfully (21727 lines)
#   bijective_map_log_80366.txt: Completed successfully (4506 lines)
#   bijective_map_log_80410.txt: Completed successfully (20283 lines)
#   bijective_map_log_80414.txt: Completed successfully (29418 lines)
#   bijective_map_log_80557.txt: Completed successfully (47524 lines)
#   bijective_map_log_80597.txt: Completed successfully (34905 lines)
#   bijective_map_log_80603.txt: Completed successfully (21568 lines)
#   bijective_map_log_80604.txt: Completed successfully (14412 lines)
#   bijective_map_log_80655.txt: Completed successfully (51745 lines)
#   bijective_map_log_80657.txt: Completed successfully (10453 lines)
#   bijective_map_log_80746.txt: Completed successfully (2497 lines)
#   bijective_map_log_80748.txt: Completed successfully (2496 lines)
#   bijective_map_log_80750.txt: Completed successfully (34314 lines)
#   bijective_map_log_80751.txt: Completed successfully (9192 lines)
#   bijective_map_log_80752.txt: Completed successfully (6375 lines)
#   bijective_map_log_80755.txt: Completed successfully (13900 lines)
#   bijective_map_log_80756.txt: Completed successfully (8119 lines)
#   bijective_map_log_80757.txt: Completed successfully (31926 lines)
#   bijective_map_log_80759.txt: Completed successfully (23297 lines)
#
# ERROR files (1):
#   bijective_map_log_43960.txt: Error found: "Error: curves topology is not correct" (3508 lines)
#
# INCOMPLETE files (177):
#   bijective_map_log_32770.txt: Did not complete (23279 lines)
#   bijective_map_log_34783.txt: Did not complete (57724 lines)
#   bijective_map_log_34785.txt: Did not complete (33970 lines)
#   bijective_map_log_35269.txt: Did not complete (25217 lines)
#   bijective_map_log_37003.txt: Did not complete (121015 lines)
#   bijective_map_log_37004.txt: Did not complete (47866 lines)
#   bijective_map_log_37266.txt: Did not complete (40313 lines)
#   bijective_map_log_37272.txt: Did not complete (21329 lines)
#   bijective_map_log_37275.txt: Did not complete (37595 lines)
#   bijective_map_log_37284.txt: Did not complete (26641 lines)
#   bijective_map_log_37289.txt: Did not complete (19685 lines)
#   bijective_map_log_37384.txt: Did not complete (32348 lines)
#   bijective_map_log_37404.txt: Did not complete (21141 lines)
#   bijective_map_log_37747.txt: Did not complete (11563 lines)
#   bijective_map_log_37765.txt: Did not complete (19046 lines)
#   bijective_map_log_37786.txt: Did not complete (25953 lines)
#   bijective_map_log_37789.txt: Did not complete (55577 lines)
#   bijective_map_log_37841.txt: Did not complete (30003 lines)
#   bijective_map_log_37991.txt: Did not complete (20736 lines)
#   bijective_map_log_38094.txt: Did not complete (14909 lines)
#   bijective_map_log_38110.txt: Did not complete (14816 lines)
#   bijective_map_log_38261.txt: Did not complete (24955 lines)
#   bijective_map_log_38290.txt: Did not complete (10673 lines)
#   bijective_map_log_39108.txt: Did not complete (34724 lines)
#   bijective_map_log_39109.txt: Did not complete (43071 lines)
#   bijective_map_log_39159.txt: Did not complete (43935 lines)
#   bijective_map_log_39160.txt: Did not complete (43127 lines)
#   bijective_map_log_39168.txt: Did not complete (30490 lines)
#   bijective_map_log_39180.txt: Did not complete (20459 lines)
#   bijective_map_log_39181.txt: Did not complete (18330 lines)
#   bijective_map_log_39208.txt: Did not complete (30877 lines)
#   bijective_map_log_39295.txt: Did not complete (44772 lines)
#   bijective_map_log_39296.txt: Did not complete (84754 lines)
#   bijective_map_log_39344.txt: Did not complete (12802 lines)
#   bijective_map_log_39368.txt: Did not complete (82252 lines)
#   bijective_map_log_39442.txt: Did not complete (28860 lines)
#   bijective_map_log_39443.txt: Did not complete (29930 lines)
#   bijective_map_log_39444.txt: Did not complete (25738 lines)
#   bijective_map_log_39445.txt: Did not complete (30603 lines)
#   bijective_map_log_39495.txt: Did not complete (22630 lines)
#   bijective_map_log_39496.txt: Did not complete (32675 lines)
#   bijective_map_log_39498.txt: Did not complete (41525 lines)
#   bijective_map_log_39499.txt: Did not complete (31552 lines)
#   bijective_map_log_39729.txt: Did not complete (7569 lines)
#   bijective_map_log_39730.txt: Did not complete (7187 lines)
#   bijective_map_log_39878.txt: Did not complete (61410 lines)
#   bijective_map_log_40051.txt: Did not complete (31229 lines)
#   bijective_map_log_40052.txt: Did not complete (31229 lines)
#   bijective_map_log_40358.txt: Did not complete (26054 lines)
#   bijective_map_log_40443.txt: Did not complete (20904 lines)
#   bijective_map_log_78319.txt: Did not complete (33547 lines)
#   bijective_map_log_78325.txt: Did not complete (13521 lines)
#   bijective_map_log_78481.txt: Did not complete (123896 lines)
#   bijective_map_log_78538.txt: Did not complete (82731 lines)
#   bijective_map_log_78659.txt: Did not complete (102645 lines)
#   bijective_map_log_78736.txt: Did not complete (20917 lines)
#   bijective_map_log_78737.txt: Did not complete (22898 lines)
#   bijective_map_log_78738.txt: Did not complete (22801 lines)
#   bijective_map_log_79073.txt: Did not complete (23081 lines)
#   bijective_map_log_79239.txt: Did not complete (53996 lines)
#   bijective_map_log_79241.txt: Did not complete (58058 lines)
#   bijective_map_log_80353.txt: Did not complete (15926 lines)
#   bijective_map_log_80354.txt: Did not complete (18764 lines)
#   bijective_map_log_80363.txt: Did not complete (5407 lines)
#   bijective_map_log_80364.txt: Did not complete (4839 lines)
#   bijective_map_log_80369.txt: Did not complete (17935 lines)
#   bijective_map_log_80370.txt: Did not complete (18483 lines)
#   bijective_map_log_80650.txt: Did not complete (114010 lines)
#   bijective_map_log_80760.txt: Did not complete (26731 lines)
#   bijective_map_log_80761.txt: Did not complete (100226 lines)
#
# EMPTY files (14):
#   bijective_map_log_39182.txt: File is empty
#   bijective_map_log_39245.txt: File is empty
#   bijective_map_log_39247.txt: File is empty
#   bijective_map_log_39880.txt: File is empty
#   bijective_map_log_40993.txt: File is empty
#   bijective_map_log_41732.txt: File is empty
#   bijective_map_log_42040.txt: File is empty
#   bijective_map_log_44900.txt: File is empty
#   bijective_map_log_44902.txt: File is empty
#   bijective_map_log_44903.txt: File is empty
#   bijective_map_log_77949.txt: File is empty
#   bijective_map_log_79954.txt: File is empty
#   bijective_map_log_79957.txt: File is empty
#   bijective_map_log_80368.txt: File is empty

# %%
# Create a DataFrame for easier analysis
df_data = []
for file_id, data in results.items():
    df_data.append({
        'file_id': int(file_id) if file_id.isdigit() else file_id,
        'filename': data['filename'],
        'status': data['status'],
        'details': data['details']
    })

df = pd.DataFrame(df_data)
if not df.empty:
    df = df.sort_values('file_id')

print("\nDataFrame created with results:")
print(df.head(10))
# Out:
# DataFrame created with results:
#    file_id                     filename      status  \
# 0    32770  bijective_map_log_32770.txt  incomplete
# 1    34783  bijective_map_log_34783.txt  incomplete
# 2    34785  bijective_map_log_34785.txt  incomplete
# 3    35269  bijective_map_log_35269.txt  incomplete
# 4    36069  bijective_map_log_36069.txt     success
# 5    36075  bijective_map_log_36075.txt     success
# 6    36082  bijective_map_log_36082.txt     success
# 7    36086  bijective_map_log_36086.txt     success
# 8    36090  bijective_map_log_36090.txt     success
# 9    36372  bijective_map_log_36372.txt     success
#
#                                details
# 0       Did not complete (23279 lines)
# 1       Did not complete (57724 lines)
# 2       Did not complete (33970 lines)
# 3       Did not complete (25217 lines)
# 4  Completed successfully (3935 lines)
# 5  Completed successfully (4201 lines)
# 6  Completed successfully (3848 lines)
# 7  Completed successfully (8889 lines)
# 8  Completed successfully (8896 lines)
# 9  Completed successfully (3940 lines)

# %%
# Create visualization
plt.figure(figsize=(12, 8))

# Pie chart
plt.subplot(2, 2, 1)
labels = []
sizes = []
colors = ['#2ecc71', '#e74c3c', '#f39c12', '#95a5a6', '#9b59b6']
color_map = {'success': '#2ecc71', 'error': '#e74c3c', 'incomplete': '#f39c12', 
             'empty': '#95a5a6', 'missing': '#9b59b6'}

for status, count in sorted(status_counts.items()):
    labels.append(f'{status.title()}\n({count})')
    sizes.append(count)

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90,
        colors=[color_map.get(status.lower(), '#95a5a6') for status in [s.split('\n')[0].lower() for s in labels]])
plt.title('Bijective Map Log Analysis Results')

# Bar chart
plt.subplot(2, 2, 2)
statuses = list(status_counts.keys())
counts = list(status_counts.values())
bars = plt.bar(statuses, counts, color=[color_map.get(s, '#95a5a6') for s in statuses])
plt.title('File Status Distribution')
plt.ylabel('Number of Files')
plt.xticks(rotation=45)

# Add value labels on bars
for bar, count in zip(bars, counts):
    plt.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 0.1,
             str(count), ha='center', va='bottom')

# Timeline of file IDs (if numeric)
if not df.empty and df['file_id'].dtype != 'object':
    plt.subplot(2, 1, 2)
    status_colors = df['status'].map(color_map)
    plt.scatter(df['file_id'], [1]*len(df), c=status_colors, alpha=0.7, s=50)
    plt.xlabel('File ID')
    plt.ylabel('')
    plt.title('File Status Timeline (by ID)')
    plt.yticks([])
    
    # Add legend
    legend_elements = []
    for status, color in color_map.items():
        if status in status_counts:
            legend_elements.append(plt.Line2D([0], [0], marker='o', color='w', 
                                            markerfacecolor=color, markersize=8, label=status.title()))
    plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Save results to CSV for further analysis
if not df.empty:
    output_file = 'bijective_map_analysis_results.csv'
    df.to_csv(output_file, index=False)
    print(f"\nResults saved to: {output_file}")
    
    # Save summary statistics
    summary_file = 'bijective_map_analysis_summary.txt'
    with open(summary_file, 'w') as f:
        f.write("Bijective Map Log Analysis Summary\n")
        f.write("=" * 40 + "\n\n")
        f.write(f"Total files analyzed: {total_files}\n\n")
        
        for status, count in sorted(status_counts.items()):
            percentage = (count / total_files) * 100
            f.write(f"{status.upper()}: {count} files ({percentage:.1f}%)\n")
    
    print(f"Summary saved to: {summary_file}")
else:
    print("No data to save")
# Out:
# Results saved to: bijective_map_analysis_results.csv
# Summary saved to: bijective_map_analysis_summary.txt

# %%
# Get all error IDs for detailed analysis
if not df.empty:
    error_ids = df[df['status'] == 'error']['file_id'].tolist()
    print(f"\nError File IDs ({len(error_ids)} total):")
    if error_ids:
        # Sort the error IDs if they are numeric
        try:
            error_ids_sorted = sorted([int(id) for id in error_ids])
            print(error_ids_sorted)
        except (ValueError, TypeError):
            # If not numeric, sort as strings
            error_ids_sorted = sorted(error_ids)
            print(error_ids_sorted)
        
        # Save error IDs to file
        error_ids_file = 'error_file_ids.txt'
        with open(error_ids_file, 'w') as f:
            f.write("Error File IDs\n")
            f.write("=" * 15 + "\n\n")
            for error_id in error_ids_sorted:
                f.write(f"{error_id}\n")
        print(f"Error IDs saved to: {error_ids_file}")
        
        # Print last 10 lines of each error file's log
        print(f"\nLast 10 lines for each error file:")
        print("=" * 50)
        for error_id in error_ids_sorted:
            log_file = f"./test_log/bijective_map_log_{error_id}.txt"
            print(f"\nFile ID: {error_id}")
            print("-" * 30)
            try:
                with open(log_file, 'r') as f:
                    lines = f.readlines()
                    last_lines = lines[-10:] if len(lines) >= 10 else lines
                    for line in last_lines:
                        print(line.rstrip())
            except FileNotFoundError:
                print(f"Log file not found: {log_file}")
            except Exception as e:
                print(f"Error reading log file: {e}")
    else:
        print("No error files found")
else:
    print("No data available to extract error IDs")
# Out:
# Error File IDs (1 total):
# [43960]
# Error IDs saved to: error_file_ids.txt
#
# Last 10 lines for each error file:
# ==================================================
#
# File ID: 43960
# ------------------------------
# curve 12 and curve 14 intersect 0 times
# intersections between curve 12 and curve 14 are correct
# --------------------------------
# curve 13 has 0 self intersections
# curve 13 and curve 14 intersect 0 times
# intersections between curve 13 and curve 14 are correct
# --------------------------------
# curve 14 has 0 self intersections
# Error: curves topology is not correct
# finished check curves topology

# %%
# Get all empty IDs for detailed analysis
if not df.empty:
    empty_ids = df[df['status'] == 'empty']['file_id'].tolist()
    print(f"\nEmpty File IDs ({len(empty_ids)} total):")
    if empty_ids:
        # Sort the empty IDs if they are numeric
        try:
            empty_ids_sorted = sorted([int(id) for id in empty_ids])
            print(empty_ids_sorted)
        except (ValueError, TypeError):
            # If not numeric, sort as strings
            empty_ids_sorted = sorted(empty_ids)
            print(empty_ids_sorted)
        
        # Save empty IDs to file
        empty_ids_file = 'empty_file_ids.txt'
        with open(empty_ids_file, 'w') as f:
            f.write("Empty File IDs\n")
            f.write("=" * 15 + "\n\n")
            for empty_id in empty_ids_sorted:
                f.write(f"{empty_id}\n")
        print(f"Empty IDs saved to: {empty_ids_file}")
        
        # Print last 10 lines of each empty file's log
        print(f"\nLast 10 lines for each empty file:")
        print("=" * 50)
        for empty_id in empty_ids_sorted:
            log_file = f"./test_log/bijective_map_log_{empty_id}.txt"
            print(f"\nFile ID: {empty_id}")
            print("-" * 30)
            try:
                with open(log_file, 'r') as f:
                    lines = f.readlines()
                    last_lines = lines[-10:] if len(lines) >= 10 else lines
                    for line in last_lines:
                        print(line.rstrip())
            except FileNotFoundError:
                print(f"Log file not found: {log_file}")
            except Exception as e:
                print(f"Error reading log file: {e}")
    else:
        print("No empty files found")
else:
    print("No data available to extract empty IDs")
# Out:
# Empty File IDs (14 total):
# [39182, 39245, 39247, 39880, 40993, 41732, 42040, 44900, 44902, 44903, 77949, 79954, 79957, 80368]
# Empty IDs saved to: empty_file_ids.txt
#
# Last 10 lines for each empty file:
# ==================================================
#
# File ID: 39182
# ------------------------------
#
# File ID: 39245
# ------------------------------
#
# File ID: 39247
# ------------------------------
#
# File ID: 39880
# ------------------------------
#
# File ID: 40993
# ------------------------------
#
# File ID: 41732
# ------------------------------
#
# File ID: 42040
# ------------------------------
#
# File ID: 44900
# ------------------------------
#
# File ID: 44902
# ------------------------------
#
# File ID: 44903
# ------------------------------
#
# File ID: 77949
# ------------------------------
#
# File ID: 79954
# ------------------------------
#
# File ID: 79957
# ------------------------------
#
# File ID: 80368
# ------------------------------
